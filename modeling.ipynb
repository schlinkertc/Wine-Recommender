# %% [markdown]
# # Content Recommender System for Wines
# ## Based on data scraped from Vivino.com and Wine-Searcher.com

# %%
import numpy as np
from class_definitions import *
import pandas as pd

df = pd.read_csv('dataset.csv').drop(columns=['index'])
df.dropna(axis=1,inplace=True)

# %% [markdown]
# ### Prepare the Data
# ##### First, calculate a weighted score based on Vivino user reviews

# %%
C = df['ratings_average'].mean()
# mininum ratings count to be considered 
m = df['ratings_count'].quantile(0.1)

# qualifying wines
df = df.loc[df['ratings_count']>=m].reset_index()

# %%
def weighted_rating(x,m=m,C=C):
    v = x['ratings_count']
    R = x['ratings_average']
    return (v/(v+m) * R) + (m/(m+v) * C)

# %%
df['score'] = df.apply(weighted_rating,axis=1)

# %% [markdown]
# ##### Next, incorporate tasting notes.
# Vivino extracts keywords from user reviews to describe how wines taste. For example, if a user mentions words like "Cherry" or "Raspberry", a "Red Fruit" tasting note is attributed to that wine. Similarly, "Pepper" or "Cinnamon" maps to a "Spices" note, and so on. We'll incorporate these notes and the associated keywords into our model.

# %%
tasting_notes=joblib.load('Wines/tasting_notes.pkl')

records = []
for t in tasting_notes:
    d = {}
    for k,v in t.items():
        d['id']=k
        d['notes']=list(
            {x['note'].split(' mentions of')[-1].replace(' notes','').strip() for x in v})
        d['tags']=list({x['tag'] for x in v})
    records.append(d)

# %%
def add_tastingNotes(x):
    wine_id = x['id']
    record = list(filter(lambda x: x['id']==wine_id,records))[0]
    notes = "".join([x+' ' for x in record['notes']])
    tags = "".join([x+' ' for x in record['tags']])
    return notes+tags

df['words'] = df.apply(add_tastingNotes,axis=1)

# %% [markdown]
# ### Create the data pipeline
# "Body" and "Acidity" are discrete variables ranked from 1-5. We'll use sklearn's Ordinal Encoder to prepare these data for modeling. We'll use One Hot Encoding for categorical variables, a Standard Scaler for numerical values, and a TF-IDF vectorizer for the tasting notes.

# %%
num_attributes = ['ranking_region','ranking_global','score']
cat_attributes = ['Region/Appellation','Grape/Blend','Food Suggestion','Wine Style','region','varietal_name','type','country_name']
ordinal_attributes = ['body','acidity']

# %%
from sklearn.preprocessing import OrdinalEncoder,StandardScaler,OneHotEncoder
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer()
ordinal_encoder = OrdinalEncoder()
one_hot = OneHotEncoder()
std_scaler = StandardScaler()

# %%
from sklearn.compose import ColumnTransformer

full_transform = ColumnTransformer([
    ('num',std_scaler,num_attributes),
    ('cat',one_hot,cat_attributes),
    ('ord',ordinal_encoder,ordinal_attributes),
    ('words',tfidf,'words')
])

matrix = full_transform.fit_transform(df)

# %% [markdown]
# ### Get similar wines
# This function takes in a Wine ID and provides us with 10 similar wines from the original dataset. It does so by computing a cosine similarity score based on our transformed matrix

# %%
from sklearn.metrics.pairwise import linear_kernel

cosine_similarity = linear_kernel(matrix,matrix)

#Construct a reverse map of indices and wine ids
indices = pd.Series(df.index, index=df['id']).drop_duplicates()

# %%
def get_recomendations(wine_id,cosine_similarity=cosine_similarity):
    idx = indices[wine_id]
    
    sim_scores = list(enumerate(cosine_similarity[idx]))
    
    sim_scores = sorted(sim_scores, key=lambda x: x[1],reverse=True)
    
    sim_scores = sim_scores[1:11]
    
    wine_indicies = [i[0] for i in sim_scores]
    
    recomended_wines = df.iloc[df['id'].iloc[wine_indicies].index]
    seed_idx = df[df['id']==wine_id].index
    name = df.iloc[seed_idx]['vivino_wine'].values[0]
    print(f"Wines similar to {name}")
    return recomended_wines[['vivino_wine','Wine Style','style','winery','region','Grape/Blend','country_name']]

# %% [markdown]
# ### Testing it out

# %%
display(df[df['id']==4470482][['vivino_wine','region','Wine Style','type','Grape/Blend','country_name']])
get_recomendations(4470482)
# Out:
#              vivino_wine  region          Wine Style type Grape/Blend  \
# 0  Stefan Bauer Zweigelt  Wagram  Savory and Classic  Red    Zweigelt
#
#   country_name
# 0      Austria
# Wines similar to Stefan Bauer Zweigelt
#                                           vivino_wine             Wine Style  \
# 30                                   Torremorón Roble       Rich and Intense
# 35                           Alma del Toro Tinto Seco       Rich and Intense
# 72                      L&C Poitout Bienommée Chablis       Green and Flinty
# 55  Patrick et Christophe Bonnefond Les Rochains C...    Bold and Structured
# 94                             Brezza Langhe Nebbiolo     Savory and Classic
# 31                      Acacia A by Acacia Chardonnay    Buttery and Complex
# 83   Quinta da Boavista - Tavares de Pina Rufia Tinto       Rich and Intense
# 11                       Tobia Viña Tobía Rioja Tinto    Bold and Structured
# 19                          Xanthos Fly By Chardonnay  Tropical and Balanced
# 82                           Lammershoek LAM Pinotage       Rich and Intense
#
#                            style                                winery  \
# 30  Spanish Ribera Del Duero Red                            Torremorón
# 35                   Spanish Red                         Alma del Toro
# 72              Burgundy Chablis                           L&C Poitout
# 55     Northern Rhône Côte-Rotie       Patrick et Christophe Bonnefond
# 94              Italian Nebbiolo                                Brezza
# 31        Californian Chardonnay                                Acacia
# 83            Portuguese Dão Red  Quinta da Boavista - Tavares de Pina
# 11             Spanish Rioja Red                                 Tobia
# 19        Californian Chardonnay                               Xanthos
# 82        South African Pinotage                           Lammershoek
#
#               region                  Grape/Blend   country_name
# 30  Ribera del Duero                  Tempranillo          Spain
# 35          Castilla                  Tempranillo          Spain
# 72           Chablis                   Chardonnay         France
# 55        Côte-Rôtie                        Syrah         France
# 94            Langhe                     Nebbiolo          Italy
# 31        California                   Chardonnay  United States
# 83               Dão         Portuguese Red Blend       Portugal
# 11             Rioja  Cabernet Sauvignon - Malbec          Spain
# 19     Sonoma County                   Chardonnay  United States
# 82         Swartland                     Pinotage   South Africa

# %%
display(df[df['id']==1478833][['vivino_wine','region','Wine Style','type','Grape/Blend','country_name']])
get_recomendations(1478833)
# Out:
#                                         vivino_wine                 region  \
# 104  Paolo Bea Pagliaro Montefalco Sagrantino Secco  Montefalco Sagrantino
#
#               Wine Style type Grape/Blend country_name
# 104  Bold and Structured  Red  Sagrantino        Italy
# Wines similar to Paolo Bea Pagliaro Montefalco Sagrantino Secco
#                                    vivino_wine           Wine Style  \
# 45         Il Palazzone Brunello di Montalcino  Bold and Structured
# 27                     Sobrero Pernanno Barolo   Savory and Classic
# 29             Brovia Brea Vigna Ca'Mia Barolo   Savory and Classic
# 52  Belle Glos Las Alturas Vineyard Pinot Noir   Light and Perfumed
# 7                    Proprieta Sperino Uvaggio   Savory and Classic
# 63                             Nervi Gattinara   Savory and Classic
# 64                             Nervi Gattinara   Savory and Classic
# 78        Billecart-Salmon Brut Rosé Champagne    Berries and Cream
# 97                   Centorri Moscato di Pavia  Aromatic and Floral
# 16         Aubert Chardonnay Larry Hyde & Sons  Buttery and Complex
#
#                      style             winery                  region  \
# 45        Italian Brunello       Il Palazzone  Brunello di Montalcino
# 27          Italian Barolo            Sobrero                  Barolo
# 29          Italian Barolo             Brovia                  Barolo
# 52  Californian Pinot Noir         Belle Glos   Santa Lucia Highlands
# 7       Northern Italy Red  Proprieta Sperino       Coste della Sesia
# 63        Italian Nebbiolo              Nervi               Gattinara
# 64        Italian Nebbiolo              Nervi               Gattinara
# 78        French Champagne   Billecart-Salmon               Champagne
# 97    Northern Italy White           Centorri               Lombardia
# 16  Napa Valley Chardonnay             Aubert            Los Carneros
#
#         Grape/Blend   country_name
# 45       Sangiovese          Italy
# 27         Nebbiolo          Italy
# 29         Nebbiolo          Italy
# 52       Pinot Noir  United States
# 7          Nebbiolo          Italy
# 63         Nebbiolo          Italy
# 64         Nebbiolo          Italy
# 78  Champagne Blend         France
# 97           Muscat          Italy
# 16       Chardonnay  United States
